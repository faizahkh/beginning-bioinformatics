# %% [markdown]
# <a href="https://colab.research.google.com/github/faizahkh/beginning-bioinformatics/blob/notebooks/Bioinformatics_Module03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1. Rename this notebook Bioinformatics_Module03.ipynb

# %%
#Task 2. print()writes to standard output (i.e. prints output to the screen)
#TASK P2.1: Print hello world

print('Hello World')
# Out:
# Hello World

# %%
#Task 3. = is the ASSIGNMENT operator (assigns values to variables)
#TASK P3.1: Ask Gemini, "Give me 3 examples to help practice understanding the assignment operator."

x = 3
x
# Out:
# 3

# %%
#Task 4: Data types and variables

type(x)
# Out:
# int

# %%
# Coding operators - Task 5 & Rosalind #1
x = 838
y = 866
z = x**2+y**2
print(f"The hypotenuse of 838 and 866 is {z}")
# Out:
# The hypotenuse of 838 and 866 is 1452200

# %%
# Problem 1

user = int(input('Please enter the first number:'))
user2 = int(input('Please enter the second number:'))
answer = print(user**2+user2**2)

print(answer)
# Out:
# Please enter the first number:838
# Please enter the second number:866
# 1452200
# None

# %%
# Task 7 - List and append

my_list = ['Hello', 'World', 'Charles Darwin']
print(my_list[1])
# Out:
# World

# %%
#TASK 7.2
my_list[2] = 'Alfred R. Wallace'
print(my_list)
# Out:
# ['Hello', 'World', 'Alfred R. Wallace']

# %%
# Task 7.3
my_list.append('Charles Darwin')
print(my_list)
# Out:
# ['Hello', 'World', 'Alfred R. Wallace', 'Charles Darwin']

# %%
# Gemini Insertion for task 7.4
my_list.insert(1,'Newton')
print(my_list)
# Out:
# ['Hello', 'Newton', 'World', 'Alfred R. Wallace', 'Charles Darwin']

# %%
# Task 8: Slicing strings and list
print(my_list[2:4])
# Out:
# ['World', 'Alfred R. Wallace']

# %%
#Task 8.2
my_string = 'HelloWorldCharlesDarwinAlfred R.Wallace'
print(my_string[32:40],my_string[5:10])
# Out:
# Wallace World

# %%
#Task 8.3 - Problem 2
rosalind = 'pGgIqKCRoeHd6LSV4vMlRsUNDdTp2qroxGogQatvNyOxWogA3JHirundo77VjihnLzzBrHqzEC2wanatina32MkBFlXVWtH7t8pNrCKm32DcM2gK6WTMYPRwyMRSk251qNfgI5Dv4RqSQkOe4IjSWrAVOVl8N8YAvQCx8PSBr.'
print((rosalind[50:56] + " " + rosalind[76:82]))
# Out:
# Hirund anatin
